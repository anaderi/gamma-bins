# %% [markdown]
# # Clustering for gevtevsimbad

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from sklearn.neighbors import DistanceMetric
from sklearn.metrics.pairwise import pairwise_distances
from sklearn import cluster
from sklearn.decomposition.pca import PCA
from sklearn.manifold import TSNE
import seaborn as sns

# %%
#path_to_gamma_bins shoud contain an absolute path to your gamma-bins directory
path_to_gamma_bins = os.path.dirname(os.getcwd()) + "/"

# %%
#name columns included in the final display
other_names = ['s_MAIN_ID', 's_class', 'gev_1FGL_Name', 'gev_CLASS1', 'tev_fermi_names', 'tev_classes', 'marked']
#from gamma bins directory
path_to_catalog = "markeddata/normalized_spectra.txt"

# %%
spectra = pd.read_csv(path_to_gamma_bins +path_to_catalog)
spectra.head()
# Out:
#    gev_nuFnu10000_100000  gev_nuFnu1000_3000  gev_nuFnu100_300  \
# 0               0.013537            0.343081          0.020826
# 1               0.013335            0.013325          0.000805
# 2               0.001682            0.042624          0.002587
# 3               0.011399            0.129145          0.001246
# 4               0.012809            0.324638          0.019706
#
#    gev_nuFnu3000_10000  gev_nuFnu300_1000  gev_nuFnu30_100  s_FLUX_U  \
# 0             0.143005           0.330419              0.0       0.0
# 1             0.014451           0.004808              0.0       0.0
# 2             0.017767           0.041051              0.0       0.0
# 3             0.070802           0.082033              0.0       0.0
# 4             0.135318           0.312657              0.0       0.0
#
#    s_FLUX_B  s_FLUX_V  s_FLUX_R   ...    tev_3TeV  tev_10TeV  tev_30TeV  \
# 0  0.000000  0.000000       0.0   ...    0.012135   0.004136   0.000407
# 1  0.004396  0.019638       0.0   ...    0.007655   0.004429   0.002622
# 2  0.000000  0.000000       0.0   ...    0.001508   0.000514   0.000051
# 3  0.000000  0.000000       0.0   ...    0.000969   0.000719   0.001111
# 4  0.000000  0.000000       0.0   ...    0.011482   0.003914   0.000385
#
#             s_MAIN_ID  s_class          gev_1FGL_Name  gev_CLASS1  \
# 0     b'SSTGC 519103'       Be  b'                  '    b'     '
# 1  b'LS  IV -05   11'        B  b'                  '    b'PWN  '
# 2        b'GCIRS  1W'        B  b'                  '    b'     '
# 3     b'[MCD2010] 18'        O  b'1FGL J1746.4-2849c'    b'pwn  '
# 4         b'GCIRS  8'        O  b'                  '    b'     '
#
#    tev_fermi_names  tev_classes  marked
# 0              b''      b'unid'       0
# 1              b''      b'unid'       0
# 2              b''      b'unid'       0
# 3              b''      b'unid'       0
# 4              b''      b'unid'       0
#
# [5 rows x 32 columns]

# %%
spectrum_columns = spectra.columns[:-len(other_names)]

# %%
def get_distance_metric(metric_function):
    if type(metric_function) == str:
        dist = DistanceMetric.get_metric(metric_function)
    else:
        dist = DistanceMetric.get_metric("pyfunc", func=metric_function)
    return dist

# %% [markdown]
# * ### earth mover's distance

# %%
# earth mover's distance
metric_function = st.wasserstein_distance
spectra_distances = pairwise_distances(spectra[spectrum_columns], metric=metric_function)
# spectra_distances = get_distance_metric(metric_function).pairwise(spectra[spectrum_columns])
#pd.DataFrame(spectra_distances).to_csv(path_to_gamma_bins +"markeddata/gevtev_spectra_EM_distances.txt", index=False)

# %%
colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])

plt.subplots(figsize=(18, 6))
plt.subplot(131)
plt.title("PCA")
pca = PCA(n_components=2, random_state=42)
spectra_2D = pca.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(132)
plt.title("TSNE, Euclidean distance")
tsne = TSNE(n_components=2, random_state=42, learning_rate=500, n_iter=1500)
spectra_2D = tsne.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(133)
plt.title("TSNE, Chosen distance")
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=200)
spectra_2D = tsne.fit_transform(spectra_distances)
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)
plt.show()

# %%
spectra_distances.min(), spectra_distances.max()
# Out:
# (0.0, 0.05197643228103741)

# %%
# visualization - tsne with Euclidean distance
# tsne = TSNE(n_components=2, random_state=42, learning_rate=500)
# spectra_2D = tsne.fit_transform(spectra[spectrum_columns])

# visualization - tsne with chosen distance
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=200)
spectra_2D = tsne.fit_transform(spectra_distances)

plt.subplots(figsize=(18, 18))
plt.subplot(3, 3, 1)

colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])
plt.title("true labels")
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 
          'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']

eps_l = [0.01 * i for i in range(5, 0, -1)]
for i, eps in enumerate(eps_l):
    dbscan = cluster.DBSCAN(eps=eps, min_samples=2)
    cluster_labels = dbscan.fit_predict(spectra_distances)

    plt.subplot(3, 3, i + 2)
    c = [colors[l] for l in cluster_labels]
    plt.title("cluster labels (eps = {:.2})".format(eps))
    plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.show()

# %%
eps = 0.04

dbscan = cluster.DBSCAN(eps=eps, min_samples=2)
cluster_labels = dbscan.fit_predict(spectra_distances)
centers = []

colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 
          'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']

col_name = 'DBSCAN_clusters_eps={}'.format(eps)
spectra[col_name] = cluster_labels
for i in set(cluster_labels):
    print("{} cluster ({})".format(i, colors[i]))
    display(spectra[spectra[col_name] == i][other_names])
    centers.append(spectra.loc[spectra[col_name] == i, spectrum_columns].mean(axis=0).values)
centers = pd.DataFrame(np.column_stack(centers).T, columns=spectrum_columns)
# Out:
# 0 cluster (tab:blue)
#                s_MAIN_ID s_class          gev_1FGL_Name gev_CLASS1  \
# 0        b'SSTGC 519103'      Be  b'                  '   b'     '
# 1     b'LS  IV -05   11'       B  b'                  '   b'PWN  '
# 4            b'GCIRS  8'       O  b'                  '   b'     '
# 38  b'2FGL J1019.0-5856'    B0Ve  b'1FGL J1018.6-5856 '   b'HMB  '
#
#          tev_fermi_names tev_classes  marked
# 0                    b''     b'unid'       0
# 1                    b''     b'unid'       0
# 4                    b''     b'unid'       0
# 38  b'1FGL J1018.6-5856'      b'bin'       1
# 1 cluster (tab:orange)
#             s_MAIN_ID s_class          gev_1FGL_Name gev_CLASS1  \
# 2        b'GCIRS  1W'       B  b'                  '   b'     '
# 5     b'[MCD2010] 13'       O  b'1FGL J1746.4-2849c'   b'pwn  '
# 6     b'[MCD2010] 13'       O  b'1FGL J1746.4-2849c'   b'pwn  '
# 56  b'[KRL2007b] 332'    B0Ve  b'                  '   b'PWN  '
#
#    tev_fermi_names tev_classes  marked
# 2              b''     b'unid'       0
# 5              b''     b'unid'       0
# 6              b''     b'unid'       0
# 56             b''     b'unid'       0
# 2 cluster (tab:green)
#              s_MAIN_ID s_class          gev_1FGL_Name gev_CLASS1  \
# 7        b'[MT91] 213'    B0Ve  b'1FGL J2032.2+4127 '   b'PSR  '
# 8        b'Schulte 21'    B0Ve  b'1FGL J2032.2+4127 '   b'PSR  '
# 9   b'LS   I +61  303'    B0Ve  b'1FGL J0240.5+6113 '   b'HMB  '
# 60      b'V* V479 Sct'    B0Ve  b'1FGL J1826.2-1450 '   b'HMB  '
#
#    tev_fermi_names tev_classes  marked
# 7              b''     b'unid'       1
# 8              b''     b'unid'       0
# 9              b''      b'bin'       1
# 60             b''      b'bin'       1
# 3 cluster (tab:red)
#                            s_MAIN_ID s_class          gev_1FGL_Name  \
# 10     b'[CHP2004] J095549.8+693934'    B0Ve  b'1FGL J0956.5+6938 '
# 11                   b'[MTK2001b] 8'    B0Ve  b'1FGL J0956.5+6938 '
# 12     b'[CHP2004] J095637.5+694137'    B0Ve  b'1FGL J0956.5+6938 '
# 13          b'CXOU J095601.7+694308'    B0Ve  b'1FGL J0956.5+6938 '
# 14          b'CXOU J095548.9+694010'    B0Ve  b'1FGL J0956.5+6938 '
# 15          b'CXOU J095527.1+693923'    B0Ve  b'1FGL J0956.5+6938 '
# 16          b'CXOU J095552.8+694020'    B0Ve  b'1FGL J0956.5+6938 '
# 17          b'CXOU J095552.4+694024'    B0Ve  b'1FGL J0956.5+6938 '
# 18          b'CXOU J095550.7+694039'    B0Ve  b'1FGL J0956.5+6938 '
# 19          b'CXOU J095547.5+694120'    B0Ve  b'1FGL J0956.5+6938 '
# 20          b'CXOU J095527.2+694050'    B0Ve  b'1FGL J0956.5+6938 '
# 21          b'CXOU J095600.7+694107'    B0Ve  b'1FGL J0956.5+6938 '
# 22          b'CXOU J095549.1+694036'    B0Ve  b'1FGL J0956.5+6938 '
# 23          b'CXOU J095546.5+694040'    B0Ve  b'1FGL J0956.5+6938 '
# 24          b'CXOU J095552.7+694045'    B0Ve  b'1FGL J0956.5+6938 '
#
b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 11   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 12   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 13   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 14   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 15   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 16   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 17   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 18   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 19   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 20   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 21   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 22   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 23   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 24   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 25   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 26   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 27   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 28   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 29   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 30   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 31   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 32   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 33   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 34   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 35   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 36   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 37   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 39   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 40   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 41   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 42   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 43   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 44   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 45   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 46   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 47   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 48   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 49   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 50   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 51   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 52   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 53   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 54   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 55   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 57   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 58   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 59   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 61   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 62   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 63   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 64   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 65   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 66   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 67   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
#
#     marked
# 10       0
# 11       0
# 12       0
# 13       0
# 14       0
# 15       0
# 16       0
# 17       0
# 18       0
# 19       0
# 20       0
# 21       0
# 22       0
# 23       0
# 24       0
# 25       0
# 26       0
# 27       0
# 28       0
# 29       0
# 30       0
# 31       0
# 32       0
# 33       0
# 34       0
# 35       0
# 36       0
# 37       0
# 39       0
# 40       0
# 41       0
# 42       0
# 43       0
# 44       0
# 45       0
# 46       0
# 47       0
# 48       0
# 49       0
# 50       0
# 51       0
# 52       0
# 53       0
# 54       0
# 55       0
# 57       0
# 58       0
# 59       0
# 61       0
# 62       0
# 63       0
# 64       0
# 65       0
# 66       0
# 67       0
# -1 cluster (tab:cyan)
#          s_MAIN_ID s_class          gev_1FGL_Name gev_CLASS1 tev_fermi_names  \
# 3  b'[MCD2010] 18'       O  b'1FGL J1746.4-2849c'   b'pwn  '             b''
#
#   tev_classes  marked
# 3     b'unid'       0

# %% [markdown]
# * ### euclidean distance

# %%
# euclidean distance
from scipy.spatial.distance import euclidean
metric_function = "euclidean"
spectra_distances = pairwise_distances(spectra[spectrum_columns], metric=metric_function)

# %%
colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])

plt.subplots(figsize=(18, 6))
plt.subplot(131)
plt.title("PCA")
pca = PCA(n_components=2, random_state=42)
spectra_2D = pca.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(132)
plt.title("TSNE, Euclidean distance")
tsne = TSNE(n_components=2, random_state=42, learning_rate=500, n_iter=1500)
spectra_2D = tsne.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(133)
plt.title("TSNE, Chosen distance")
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=500)
spectra_2D = tsne.fit_transform(spectra_distances)
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)
plt.show()

# %%
spectra_distances.min(), spectra_distances.max()
# Out:
# (0.0, 1.0466066491817638)

# %%
# visualization - tsne with Euclidean distance
# tsne = TSNE(n_components=2, random_state=42, learning_rate=500)
# spectra_2D = tsne.fit_transform(spectra[spectrum_columns])

# visualization - tsne with chosen distance
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=500)
spectra_2D = tsne.fit_transform(spectra_distances)

plt.subplots(figsize=(18, 18))
plt.subplot(3, 3, 1)

colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])
plt.title("true labels")
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 
          'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']

eps_l = [0.1 * i for i in range(10, 0, -2)] + [0.1]
for i, eps in enumerate(eps_l):
    dbscan = cluster.DBSCAN(eps=eps, min_samples=2)
    cluster_labels = dbscan.fit_predict(spectra_distances)

    plt.subplot(3, 3, i + 2)
    c = [colors[l] for l in cluster_labels]
    plt.title("cluster labels (eps = {:.2})".format(eps))
    plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.show()

# %%
eps = 0.6

dbscan = cluster.DBSCAN(eps=eps, min_samples=2)
cluster_labels = dbscan.fit_predict(spectra_distances)
centers = []

colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 
          'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']

col_name = 'DBSCAN_clusters_eps={}'.format(eps)
spectra[col_name] = cluster_labels
for i in set(cluster_labels):
    print("{} cluster ({})".format(i, colors[i]))
    display(spectra[spectra[col_name] == i][other_names])
    centers.append(spectra.loc[spectra[col_name] == i, spectrum_columns].mean(axis=0).values)
centers = pd.DataFrame(np.column_stack(centers).T, columns=spectrum_columns)
# Out:
# 0 cluster (tab:blue)
#          s_MAIN_ID s_class          gev_1FGL_Name gev_CLASS1 tev_fermi_names  \
# 0  b'SSTGC 519103'      Be  b'                  '   b'     '             b''
# 4      b'GCIRS  8'       O  b'                  '   b'     '             b''
#
#   tev_classes  marked
# 0     b'unid'       0
# 4     b'unid'       0
# 1 cluster (tab:orange)
#              s_MAIN_ID s_class          gev_1FGL_Name gev_CLASS1  \
# 1   b'LS  IV -05   11'       B  b'                  '   b'PWN  '
# 7        b'[MT91] 213'    B0Ve  b'1FGL J2032.2+4127 '   b'PSR  '
# 8        b'Schulte 21'    B0Ve  b'1FGL J2032.2+4127 '   b'PSR  '
# 9   b'LS   I +61  303'    B0Ve  b'1FGL J0240.5+6113 '   b'HMB  '
# 60      b'V* V479 Sct'    B0Ve  b'1FGL J1826.2-1450 '   b'HMB  '
#
#    tev_fermi_names tev_classes  marked
# 1              b''     b'unid'       0
# 7              b''     b'unid'       1
# 8              b''     b'unid'       0
# 9              b''      b'bin'       1
# 60             b''      b'bin'       1
# 2 cluster (tab:green)
#             s_MAIN_ID s_class          gev_1FGL_Name gev_CLASS1  \
# 2        b'GCIRS  1W'       B  b'                  '   b'     '
# 5     b'[MCD2010] 13'       O  b'1FGL J1746.4-2849c'   b'pwn  '
# 6     b'[MCD2010] 13'       O  b'1FGL J1746.4-2849c'   b'pwn  '
# 56  b'[KRL2007b] 332'    B0Ve  b'                  '   b'PWN  '
#
#    tev_fermi_names tev_classes  marked
# 2              b''     b'unid'       0
# 5              b''     b'unid'       0
# 6              b''     b'unid'       0
# 56             b''     b'unid'       0
# 3 cluster (tab:red)
#                            s_MAIN_ID s_class          gev_1FGL_Name  \
# 10     b'[CHP2004] J095549.8+693934'    B0Ve  b'1FGL J0956.5+6938 '
694043'    B0Ve  b'1FGL J0956.5+6938 '
# 52          b'CXOU J095608.0+694139'    B0Ve  b'1FGL J0956.5+6938 '
# 53          b'CXOU J095624.6+694256'    B0Ve  b'1FGL J0956.5+6938 '
# 54        b'CXOM82 J095538.3+694030'    B0Ve  b'1FGL J0956.5+6938 '
# 55          b'CXOU J095531.8+693957'    B0Ve  b'1FGL J0956.5+6938 '
# 57          b'CXOU J095553.3+694101'    B0Ve  b'1FGL J0956.5+6938 '
# 58          b'CXOU J095546.1+694026'    B0Ve  b'1FGL J0956.5+6938 '
# 59     b'[CHP2004] J095619.6+694146'    B0Ve  b'1FGL J0956.5+6938 '
# 61          b'CXOU J095510.7+693955'    B0Ve  b'1FGL J0956.5+6938 '
# 62          b'CXOU J095547.4+694059'    B0Ve  b'1FGL J0956.5+6938 '
# 63          b'CXOU J095553.9+694045'    B0Ve  b'1FGL J0956.5+6938 '
# 64        b'CXOM82 J095550.5+694022'    B0Ve  b'1FGL J0956.5+6938 '
# 65          b'CXOU J095615.2+694142'    B0Ve  b'1FGL J0956.5+6938 '
# 66          b'CXOU J095553.2+694052'    B0Ve  b'1FGL J0956.5+6938 '
# 67          b'CXOU J095550.1+694034'    B0Ve  b'1FGL J0956.5+6938 '
#
#    gev_CLASS1                                    tev_fermi_names tev_classes  \
# 10   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 11   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 12   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 13   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 14   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 15   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 16   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 17   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 18   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 19   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 20   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 21   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 22   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 23   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 24   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 25   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 26   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 27   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 28   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 29   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 30   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 31   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 32   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 33   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 34   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 35   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 36   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 37   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 39   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 40   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 41   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 42   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 43   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 44   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 45   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 46   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 47   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 48   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 49   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 50   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 51   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 52   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 53   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 54   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 55   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 57   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 58   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 59   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 61   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 62   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 63   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 64   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 65   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 66   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 67   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
#
#     marked
# 10       0
# 11       0
# 12       0
# 13       0
# 14       0
# 15       0
# 16       0
# 17       0
# 18       0
# 19       0
# 20       0
# 21       0
# 22       0
# 23       0
# 24       0
# 25       0
# 26       0
# 27       0
# 28       0
# 29       0
# 30       0
# 31       0
# 32       0
# 33       0
# 34       0
# 35       0
# 36       0
# 37       0
# 39       0
# 40       0
# 41       0
# 42       0
# 43       0
# 44       0
# 45       0
# 46       0
# 47       0
# 48       0
# 49       0
# 50       0
# 51       0
# 52       0
# 53       0
# 54       0
# 55       0
# 57       0
# 58       0
# 59       0
# 61       0
# 62       0
# 63       0
# 64       0
# 65       0
# 66       0
# 67       0
# -1 cluster (tab:cyan)
#                s_MAIN_ID s_class          gev_1FGL_Name gev_CLASS1  \
# 3        b'[MCD2010] 18'       O  b'1FGL J1746.4-2849c'   b'pwn  '
# 38  b'2FGL J1019.0-5856'    B0Ve  b'1FGL J1018.6-5856 '   b'HMB  '
#
#          tev_fermi_names tev_classes  marked
# 3                    b''     b'unid'       0
# 38  b'1FGL J1018.6-5856'      b'bin'       1

# %% [markdown]
# * ### cosine distance

# %%
# cosine distance
# from scipy.spatial.distance import cosine
metric_function = "cosine"
spectra_distances = pairwise_distances(spectra[spectrum_columns], metric=metric_function)

# %%
colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])

plt.subplots(figsize=(18, 6))
plt.subplot(131)
plt.title("PCA")
pca = PCA(n_components=2, random_state=42)
spectra_2D = pca.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(132)
plt.title("TSNE, Euclidean distance")
tsne = TSNE(n_components=2, random_state=42, learning_rate=500, n_iter=1500)
spectra_2D = tsne.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(133)
plt.title("TSNE, Chosen distance")
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=400)
spectra_2D = tsne.fit_transform(spectra_distances)
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)
plt.show()

# %%
spectra_distances.min(), spectra_distances.max()
# Out:
# (0.0, 0.9854300306680722)

# %%
# visualization - tsne with Euclidean distance
# tsne = TSNE(n_components=2, random_state=42, learning_rate=500)
# spectra_2D = tsne.fit_transform(spectra[spectrum_columns])

# visualization - tsne with chosen distance
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=400)
spectra_2D = tsne.fit_transform(spectra_distances)

plt.subplots(figsize=(18, 18))
plt.subplot(3, 3, 1)

colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])
plt.title("true labels")
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 
          'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']

eps_l = [0.1 * i for i in range(10, 0, -2)] + [0.1]
for i, eps in enumerate(eps_l):
    dbscan = cluster.DBSCAN(eps=eps, min_samples=2)
    cluster_labels = dbscan.fit_predict(spectra_distances)

    plt.subplot(3, 3, i + 2)
    c = [colors[l] for l in cluster_labels]
    plt.title("cluster labels (eps = {:.2})".format(eps))
    plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.show()

# %%
eps = 0.2

dbscan = cluster.DBSCAN(eps=eps, min_samples=2)
cluster_labels = dbscan.fit_predict(spectra_distances)
centers = []

colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 
          'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']

col_name = 'DBSCAN_clusters_eps={}'.format(eps)
spectra[col_name] = cluster_labels
for i in set(cluster_labels):
    print("{} cluster ({})".format(i, colors[i]))
    display(spectra[spectra[col_name] == i][other_names])
    centers.append(spectra.loc[spectra[col_name] == i, spectrum_columns].mean(axis=0).values)
centers = pd.DataFrame(np.column_stack(centers).T, columns=spectrum_columns)
# Out:
# 0 cluster (tab:blue)
#          s_MAIN_ID s_class          gev_1FGL_Name gev_CLASS1 tev_fermi_names  \
# 2     b'GCIRS  1W'       B  b'                  '   b'     '             b''
# 5  b'[MCD2010] 13'       O  b'1FGL J1746.4-2849c'   b'pwn  '             b''
# 6  b'[MCD2010] 13'       O  b'1FGL J1746.4-2849c'   b'pwn  
694043'    B0Ve  b'1FGL J0956.5+6938 '
# 46          b'CXOU J095551.0+694050'    B0Ve  b'1FGL J0956.5+6938 '
# 47          b'CXOU J095554.9+694038'    B0Ve  b'1FGL J0956.5+6938 '
# 48          b'CXOU J095632.1+694127'    B0Ve  b'1FGL J0956.5+6938 '
# 49                 b'NAME M82 ULX-1'    B0Ve  b'1FGL J0956.5+6938 '
# 50     b'[CHP2004] J095630.9+694220'    B0Ve  b'1FGL J0956.5+6938 '
# 51          b'CXOU J095550.6+694043'    B0Ve  b'1FGL J0956.5+6938 '
# 52          b'CXOU J095608.0+694139'    B0Ve  b'1FGL J0956.5+6938 '
# 53          b'CXOU J095624.6+694256'    B0Ve  b'1FGL J0956.5+6938 '
# 54        b'CXOM82 J095538.3+694030'    B0Ve  b'1FGL J0956.5+6938 '
# 55          b'CXOU J095531.8+693957'    B0Ve  b'1FGL J0956.5+6938 '
# 57          b'CXOU J095553.3+694101'    B0Ve  b'1FGL J0956.5+6938 '
# 58          b'CXOU J095546.1+694026'    B0Ve  b'1FGL J0956.5+6938 '
# 59     b'[CHP2004] J095619.6+694146'    B0Ve  b'1FGL J0956.5+6938 '
# 61          b'CXOU J095510.7+693955'    B0Ve  b'1FGL J0956.5+6938 '
# 62          b'CXOU J095547.4+694059'    B0Ve  b'1FGL J0956.5+6938 '
# 63          b'CXOU J095553.9+694045'    B0Ve  b'1FGL J0956.5+6938 '
# 64        b'CXOM82 J095550.5+694022'    B0Ve  b'1FGL J0956.5+6938 '
# 65          b'CXOU J095615.2+694142'    B0Ve  b'1FGL J0956.5+6938 '
# 66          b'CXOU J095553.2+694052'    B0Ve  b'1FGL J0956.5+6938 '
# 67          b'CXOU J095550.1+694034'    B0Ve  b'1FGL J0956.5+6938 '
#
#    gev_CLASS1                                    tev_fermi_names tev_classes  \
# 10   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 11   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 12   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 13   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 14   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 15   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 16   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 17   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 18   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 19   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 20   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 21   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 22   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 23   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 24   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 25   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 26   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 27   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 28   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 29   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 30   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 31   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 32   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 33   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 34   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 35   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 36   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 37   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 39   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 40   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 41   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 42   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 43   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 44   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 45   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 46   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 47   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 48   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 49   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 50   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 51   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 52   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 53   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 54   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 55   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 57   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 58   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 59   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 61   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 62   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 63   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 64   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 65   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 66   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
# 67   b'sbg  '  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'
#
#     marked
# 10       0
# 11       0
# 12       0
# 13       0
# 14       0
# 15       0
# 16       0
# 17       0
# 18       0
# 19       0
# 20       0
# 21       0
# 22       0
# 23       0
# 24       0
# 25       0
# 26       0
# 27       0
# 28       0
# 29       0
# 30       0
# 31       0
# 32       0
# 33       0
# 34       0
# 35       0
# 36       0
# 37       0
# 39       0
# 40       0
# 41       0
# 42       0
# 43       0
# 44       0
# 45       0
# 46       0
# 47       0
# 48       0
# 49       0
# 50       0
# 51       0
# 52       0
# 53       0
# 54       0
# 55       0
# 57       0
# 58       0
# 59       0
# 61       0
# 62       0
# 63       0
# 64       0
# 65       0
# 66       0
# 67       0
# -1 cluster (tab:cyan)
#                s_MAIN_ID s_class          gev_1FGL_Name gev_CLASS1  \
# 0        b'SSTGC 519103'      Be  b'                  '   b'     '
# 1     b'LS  IV -05   11'       B  b'                  '   b'PWN  '
# 3        b'[MCD2010] 18'       O  b'1FGL J1746.4-2849c'   b'pwn  '
# 4            b'GCIRS  8'       O  b'                  '   b'     '
# 38  b'2FGL J1019.0-5856'    B0Ve  b'1FGL J1018.6-5856 '   b'HMB  '
# 56     b'[KRL2007b] 332'    B0Ve  b'                  '   b'PWN  '
#
#          tev_fermi_names tev_classes  marked
# 0                    b''     b'unid'       0
# 1                    b''     b'unid'       0
# 3                    b''     b'unid'       0
# 4                    b''     b'unid'       0
# 38  b'1FGL J1018.6-5856'      b'bin'       1
# 56                   b''     b'unid'       0

# %% [markdown]
# * ### energy distance

# %%
# energy distance
metric_function = st.energy_distance
spectra_distances = pairwise_distances(spectra[spectrum_columns], metric=metric_function)

# %%
colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])

plt.subplots(figsize=(18, 6))
plt.subplot(131)
plt.title("PCA")
pca = PCA(n_components=2, random_state=42)
spectra_2D = pca.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(132)
plt.title("TSNE, Euclidean distance")
tsne = TSNE(n_components=2, random_state=42, learning_rate=500, n_iter=1500)
spectra_2D = tsne.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(133)
plt.title("TSNE, Chosen distance")
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=300)
spectra_2D = tsne.fit_transform(spectra_distances)
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)
plt.show()

# %%
spectra_distances.min(), spectra_distances.max()
# Out:
# (0.0, 0.09591660696808199)

# %%
# visualization - tsne with Euclidean distance
# tsne = TSNE(n_components=2, random_state=42, learning_rate=500)
# spectra_2D = tsne.fit_transform(spectra[spectrum_columns])

# visualization - tsne with chosen distance
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=300)
spectra_2D = tsne.fit_transform(spectra_distances)

plt.subplots(figsize=(18, 18))
plt.subplot(3, 3, 1)

colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])
plt.title("true labels")
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 
          'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']

eps_l = [0.01 * i for i in range(10, 0, -2)] + [0.01]
for i, eps in enumerate(eps_l):
    dbscan = cluster.DBSCAN(eps=eps, min_samples=2)
    cluster_labels = dbscan.fit_predict(spectra_distances)

    plt.subplot(3, 3, i + 2)
    c = [colors[l] for l in cluster_labels]
    plt.title("cluster labels (eps = {:.2})".format(eps))
    plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.show()

# %%
eps = 0.06

dbscan = cluster.DBSCAN(eps=eps, min_samples=2)
cluster_labels = dbscan.fit_predict(spectra_distances)
centers = []

colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 
          'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']

col_name = 'DBSCAN_clusters_eps={}'.format(eps)
spectra[col_name] = cluster_labels
for i in set(cluster_labels):
    print("{} cluster ({})".format(i, colors[i]))
    display(spectra[spectra[col_name] == i][other_names])
    centers.append(spectra.loc[spectra[col_name] == i, spectrum_columns].mean(axis=0).values)
centers = pd.DataFrame(np.column_stack(centers).T, columns=spectrum_columns)
# Out:
# 0 cluster (tab:blue)
#          s_MAIN_ID s_class          gev_1FGL_Name gev_CLASS1 tev_fermi_names  \
# 0  b'SSTGC 519103'      Be  b'                  '   b'     '             b''
# 4      b'GCIRS  8'       O  b'                  '   b'     '             b''
#
#   tev_classes  marked
# 0     b'unid'       0
# 4     b'unid'       0
# 1 cluster (tab:orange)
#          s_MAIN_ID s_class          gev_1FGL_Name gev_CLASS1 tev_fermi_names  \
# 2     b'GCIRS  1W'       B  b'                  '   b'     '             b''
# 5  b'[MCD2010] 13'       O  b'1FGL J1746.4-2849c'   b'pwn  '             b''
# 6  b'[MCD2010] 13'       O  b'1FGL J1746.4-2849c'   b'pwn  '             b''
#
#   tev_classes  marked
# 2     b'unid'       0
# 5     b'unid'       0
# 6     b'unid'       0
# 2 cluster (tab:green)
#              s_MAIN_ID s_class          gev_1FGL_Name gev_CLASS1  \
# 7        b'[MT91] 213'    B0Ve  b'1FGL J2032.2+4127 '   b'PSR  '
#