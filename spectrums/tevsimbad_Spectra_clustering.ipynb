# %% [markdown]
# # Clustering for tevsimbad

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from sklearn.neighbors import DistanceMetric
from sklearn.metrics.pairwise import pairwise_distances
from sklearn import cluster
from sklearn.decomposition.pca import PCA
from sklearn.manifold import TSNE
import seaborn as sns

# %%
#path_to_gamma_bins shoud contain an absolute path to your gamma-bins directory
path_to_gamma_bins = os.path.dirname(os.getcwd()) + "/"

# %%
#name columns included in the final display
other_names = ['s_MAIN_ID', 's_class',  'tev_fermi_names', 'tev_classes', 'marked']
#from gamma bins directory
path_to_catalog = "markeddata/tevsimbad_TeVspectrum_normalized.txt"

# %%
spectra = pd.read_csv(path_to_gamma_bins +path_to_catalog)
spectra.head()
# Out:
#    s_FLUX_U  s_FLUX_B  s_FLUX_V  s_FLUX_R  s_FLUX_I  s_FLUX_G  s_FLUX_J  \
# 0       0.0  0.000000  0.000000  0.000060  0.000000  0.000143  0.001702
# 1       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000338
# 2       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000009
# 3       0.0  0.027707  0.045983  0.000000  0.000000  0.000000  0.132615
# 4       0.0  0.000531  0.000618  0.000343  0.000474  0.000618  0.000385
#
#    s_FLUX_H  s_FLUX_K  s_FLUX_u  ...    tev_0.3TeV  tev_1TeV  tev_3TeV  \
# 0  0.003243  0.007779       0.0  ...      0.484812  0.272675  0.056902
# 1  0.019565  0.869940       0.0  ...      0.045760  0.029010  0.025940
# 2  0.002454  0.616424       0.0  ...      0.148664  0.120621  0.081368
# 3  0.170842  0.205397       0.0  ...      0.003439  0.230194  0.136930
# 4  0.000260  0.000244       0.0  ...      0.489456  0.275287  0.057447
#
#    tev_10TeV  tev_30TeV                     s_MAIN_ID  s_class  \
# 0   0.037315   0.135368           b'UCAC4 105-013663'       Be
# 1   0.008455   0.000992    b'MSX6C G331.5487-00.5364'       Be
# 2   0.027734   0.002726               b'SSTGC 519103'       Be
# 3   0.045784   0.001110                    b'RMC 141'        B
# 4   0.037672   0.136665  b'[AAA97b] J053648.7-691700'        B
#
#    tev_fermi_names  tev_classes marked
# 0              b''     b'other'      0
# 1              b''      b'unid'      0
# 2              b''      b'unid'      0
# 3              b''       b'pwn'      0
# 4              b''     b'other'      0
#
# [5 rows x 24 columns]

# %%
spectrum_columns = spectra.columns[:-len(other_names)]

# %%
def get_distance_metric(metric_function):
    if type(metric_function) == str:
        dist = DistanceMetric.get_metric(metric_function)
    else:
        dist = DistanceMetric.get_metric("pyfunc", func=metric_function)
    return dist

# %% [markdown]
# * ### earth mover's distance

# %%
# earth mover's distance
metric_function = st.wasserstein_distance
spectra_distances = pairwise_distances(spectra[spectrum_columns], metric=metric_function)
# spectra_distances = get_distance_metric(metric_function).pairwise(spectra[spectrum_columns])
#pd.DataFrame(spectra_distances).to_csv(path_to_gamma_bins +"markeddata/gevtev_spectra_EM_distances.txt", index=False)

# %%
colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])

plt.subplots(figsize=(18, 6))
plt.subplot(131)
plt.title("PCA")
pca = PCA(n_components=2, random_state=42)
spectra_2D = pca.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(132)
plt.title("TSNE, Euclidean distance")
tsne = TSNE(n_components=2, random_state=42, learning_rate=500, n_iter=1500)
spectra_2D = tsne.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(133)
plt.title("TSNE, Chosen distance")
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=600)
spectra_2D = tsne.fit_transform(spectra_distances)
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)
plt.show()

# %%
# visualization - tsne with Euclidean distance
# tsne = TSNE(n_components=2, random_state=42, learning_rate=500)
# spectra_2D = tsne.fit_transform(spectra[spectrum_columns])

# visualization - tsne with chosen distance
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=600)
spectra_2D = tsne.fit_transform(spectra_distances)

plt.subplots(figsize=(18, 18))
plt.subplot(3, 3, 1)

colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])
plt.title("true labels")
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 
          'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']

for n in range(2, 10):
    kmeans = cluster.KMeans(n_clusters=n, random_state=42)
    cluster_labels = kmeans.fit_predict(spectra_distances)

    plt.subplot(3, 3, n)
    c = [colors[l] for l in cluster_labels]
    plt.title("cluster labels ({} clusters)".format(n))
    plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)
    
plt.show()

# %%
n = 5

kmeans = cluster.KMeans(n_clusters=n, random_state=42)
cluster_labels = kmeans.fit_predict(spectra_distances)
centers = []

spectra['KMeans_clusters_' + str(n)] = cluster_labels
for i in range(n):
    print("{} cluster".format(i))
    display(spectra[spectra['KMeans_clusters_' + str(n)] == i][other_names])
    centers.append(spectra.loc[spectra['KMeans_clusters_' + str(n)] == i, spectrum_columns].mean(axis=0).values)
centers = pd.DataFrame(np.column_stack(centers).T, columns=spectrum_columns)

# centroids
print("centroids:")
display(centers)
# plt.figure(figsize=(20, 10))
# sns.heatmap(centers, vmin=0, vmax=1)
# plt.show()
# Out:
# 0 cluster
#                             s_MAIN_ID s_class tev_fermi_names tev_classes  \
# 5               b'OGLE LMC-ECL-20994'       B             b''      b'pwn'
# 15  b'SSTISAGE1C J053736.75-690633.4'       B             b''      b'pwn'
# 17     b'Cl* NGC 2070    SMB     455'       O             b''      b'pwn'
# 18     b'Cl* NGC 2070    SMB     206'       O             b''      b'pwn'
# 19     b'Cl* NGC 2070    SMB     163'       O             b''      b'pwn'
# 20              b'OGLE LMC-ECL-21453'       O             b''      b'pwn'
# 21              b'OGLE LMC-ECL-21400'       O             b''      b'pwn'
# 26                        b'VFTS 318'       O             b''      b'pwn'
# 27                        b'VFTS 183'    B0Ve             b''      b'pwn'
# 28              b'OGLE LMC-ECL-21065'    B0Ve             b''      b'pwn'
# 29         b'2MASS J05371136-6905041'    B0Ve             b''      b'pwn'
# 31                     b'[ST92] 1-31'    B0Ve             b''      b'pwn'
# 33     b'Cl* NGC 2070    SMB     372'    B0Ve             b''      b'pwn'
# 36                      b'[MT91] 213'    B0Ve             b''     b'unid'
# 39                         b'VFTS 50'    B0Ve             b''      b'pwn'
# 40                     b'[P93]   287'    B0Ve             b''      b'pwn'
# 41                     b'[P93] 10008'    B0Ve             b''      b'pwn'
# 42                        b'VFTS 347'    B0Ve             b''      b'pwn'
# 44                        b'VFTS 214'    B0Ve             b''      b'pwn'
# 45                        b'VFTS 610'    B0Ve             b''      b'pwn'
# 46                         b'VFTS 54'    B0Ve             b''      b'pwn'
# 47                     b'[P93]  1570'    B0Ve             b''      b'pwn'
# 50                     b'[P93]   930'    B0Ve             b''      b'pwn'
# 52       b'[AAA97b] J053634.4-691522'    B0Ve             b''      b'pwn'
# 53                        b'VFTS 313'    B0Ve             b''      b'pwn'
# 54                     b'[P93]  1235'    B0Ve             b''      b'pwn'
# 55                        b'VFTS 534'    B0Ve             b''      b'pwn'
# 56                        b'VFTS 374'    B0Ve             b''      b'pwn'
# 57              b'OGLE LMC-ECL-21425'    B0Ve             b''      b'pwn'
# 58         b'2MASS J05374020-6910068'    B0Ve             b''      b'pwn'
# 59                 b'LS   I +61  303'    B0Ve             b''      b'bin'
# 60                       b'HD 259440'    B0Ve             b''      b'bin'
# 71           b'XMMU J053841.7-690514'    B0Ve             b''      b'pwn'
# 74                    b'CPD-63  2495'    B0Ve             b''      b'bin'
#
#     marked
# 5        0
# 15       0
# 17       0
# 18       0
# 19       0
# 20       0
# 21       0
# 26       0
# 27       0
# 28       0
# 29       0
# 31       0
# 33       0
# 36       0
# 39       0
# 40       0
# 41       0
# 42       0
# 44       0
# 45       0
# 46       0
# 47       0
# 50       0
# 52       0
# 53       0
# 54       0
# 55       0
# 56       0
# 57       0
# 58       0
# 59       1
# 60       1
# 71       0
# 74       1
# 1 cluster
#                             s_MAIN_ID s_class  \
# 61      b'[CHP2004] J095549.8+693934'    B0Ve
# 62                    b'[MTK2001b] 8'    B0Ve
# 63      b'[CHP2004] J095637.5+694137'    B0Ve
# 64           b'CXOU J095601.7+694308'    B0Ve
# 65           b'CXOU J095548.9+694010'    B0Ve
# 66           b'CXOU J095527.1+693923'    B0Ve
# 67           b'CXOU J095552.8+694020'    B0Ve
# 68           b'CXOU J095552.4+694024'    B0Ve
# 69           b'CXOU J095550.7+694039'    B0Ve
# 70           b'CXOU J095547.5+694120'    B0Ve
# 72           b'CXOU J095527.2+694050'    B0Ve
# 73           b'CXOU J095600.7+694107'    B0Ve
# 75           b'CXOU J095549.1+694036'    B0Ve
# 76           b'CXOU J095546.5+694040'    B0Ve
# 77           b'CXOU J095552.7+694045'    B0Ve
# 78           b'CXOU J095622.7+694134'    B0Ve
# 79           b'CXOU J095551.4+694035'    B0Ve
# 80           b'CXOU J095553.0+694048'    B0Ve
# 81           b'CXOU J095614.7+694249'    B0Ve
# 82           b'CXOU J095550.5+694056'    B0Ve
# 83           b'CXOU J095544.8+694100'    B0Ve
# 84           b'CXOU J095550.2+694039'    B0Ve
# 85            b'[RVZ2004] 40.49+57.4'    B0Ve
# 86           b'CXOU J095615.1+693951'    B0Ve
# 87   b'[SST2011] J095554.56+694100.4'    B0Ve
# 88           b'CXOU J095550.9+694044'    B0Ve
# 89           b'CXOU J095552.2+694042'    B0Ve
# 90           b'CXOU J095621.2+694224'    B0Ve
# 92           b'CXOU J095554.1+694039'    B0Ve
# 94   b'[SST2011] J095552.13+694053.1'    B0Ve
# 95           b'CXOU J095534.5+693823'    B0Ve
# 96           b'CXOU J095551.2+694012'    B0Ve
# 97           b'CXOU J095555.1+694027'    B0Ve
# 98           b'CXOU J095551.3+694043'    B0Ve
# 99           b'CXOU J095551.0+694050'    B0Ve
# 100          b'CXOU J095554.9+694038'    B0Ve
# 101          b'CXOU J095632.1+694127'    B0Ve
# 102                 b'NAME M82 ULX-1'    B0Ve
# 103     b'[CHP2004] J095630.9+694220'    B0Ve
# 104          b'CXOU J095550.6+694043'    B0Ve
# 106          b'CXOU J095608.0+694139'    B0Ve
# 107          b'CXOU J095624.6+694256'    B0Ve
# 109          b'CXOU J095531.8+693957'    B0Ve
# 111          b'CXOU J095553.3+694101'    B0Ve
# 112          b'CXOU J095546.1+694026'    B0Ve
# 113     b'[CHP2004] J095619.6+694146'    B0Ve
# 115          b'CXOU J095510.7+693955'    B0Ve
# 116          b'CXOU J095547.4+694059'    B0Ve
# 118          b'CXOU J095553.9+694045'    B0Ve
# 119        b'CXOM82 J095550.5+694022'    B0Ve
# 120          b'CXOU J095615.2+694142'    B0Ve
# 121          b'CXOU J095553.2+694052'    B0Ve
# 122          b'CXOU J095550.1+694034'    B0Ve
#
#                                        tev_fermi_names tev_classes  marked
# 61   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 62   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 63   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 64   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 65   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 66   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 67   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 68   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 69   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 70   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 72   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 73   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 75   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 76   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 77   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 78   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 79   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 80   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 81   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 82   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 83   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 84   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 85   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 86   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 87   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 88   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 89   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 90   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 92   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 94   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 95   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 96   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 97   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 98   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 99   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 100  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 101  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 102  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 103  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 104  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 106  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 107  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 109  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 111  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 112  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 113  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 115  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 116  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 118  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 119  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 120  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 121  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 122  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 2 cluster
#                       s_MAIN_ID s_class tev_fermi_names tev_classes  marked
# 1    b'MSX6C G331.5487-00.5364'      Be             b''     b'unid'       0
# 12                 b'GCIRS  1W'       B             b''     b'unid'       0
# 22              b'[MCD2010] 18'       O             b''     b'unid'       0
# 24              b'[MCD2010] 13'       O             b''     b'unid'       0
# 25              b'[MCD2010] 13'       O             b''     b'unid'       0
# 110           b'[KRL2007b] 332'    B0Ve             b''     b'unid'       0
# 3 cluster
#                 s_MAIN_ID s_class       tev_fermi_names tev_classes  marked
# 3              b'RMC 141'       B                   b''      b'pwn'       0
# 16        b'CPD-69   416'       B                   b''    b'other'       0
# 49             b'RMC 142'    B0Ve                   b''      b'pwn'       0
# 91   b'2FGL J1019.0-5856'    B0Ve  b'1FGL J1018.6-5856'      b'bin'       1
# 117           b'Brey  84'    B0Ve                   b''      b'pwn'       0
# 4 cluster
#                           s_MAIN_ID s_class  \
# 0               b'UCAC4 105-013663'      Be
# 2                   b'SSTGC 519103'      Be
# 4      b'[AAA97b] J053648.7-691700'       B
# 6                   b'[ST92] 2-62B'       B
# 7                    b'[KKM2013] 7'       B
# 8                    b'[ST92] 2-62'       B
# 9                         b'HTR 13'       B
# 10               b'LS  IV -05   11'       B
# 11            b'[M2002] LMC 164553'       B
# 13            b'[M2002] LMC 161594'       B
# 14   b'Cl* NGC 2070    SMB     283'       B
# 23                      b'GCIRS  8'       O
# 30                     b'HD  43582'    B0Ve
# 32              b'[LSB2000] Star 2'    B0Ve
# 34               b'UCAC2   1802729'    B0Ve
# 35                   b'[ST92] 2-27'    B0Ve
# 37       b'2MASS J05384705-6905016'    B0Ve
# 38                    b'[ST92] 2-8'    B0Ve
# 43            b'[M2002] LMC 164299'    B0Ve
# 48                    b'Schulte 21'    B0Ve
# 51     b'[AAA97b] J053634.4-691522'    B0Ve
# 93                     b'SN 2004am'    B0Ve
# 105           b'2FHL J1633.5-4746e'    B0Ve
# 108      b'CXOM82 J095538.3+694030'    B0Ve
# 114                  b'V* V479 Sct'    B0Ve
#
#                                        tev_fermi_names tev_classes  marked
# 0                                                  b''    b'other'       0
# 2                                                  b''     b'unid'       0
# 4                                                  b''    b'other'       0
# 6                                                  b''    b'other'       0
# 7                                                  b''  b'pwn,snr'       0
# 8                                                  b''    b'other'       0
# 9                                                  b''      b'pwn'       0
# 10                                                 b''     b'unid'       0
# 11                                                 b''    b'other'       0
# 13                                                 b''    b'other'       0
# 14                                                 b''      b'pwn'       0
# 23                                                 b''     b'unid'       0
# 30                                                 b''      b'snr'       0
# 32                                                 b''    b'other'       0
# 34                                                 b''    b'other'       0
# 35                                                 b''    b'other'       0
# 37                                                 b''      b'pwn'       0
# 38                                                 b''    b'other'       0
# 43                                                 b''    b'other'       0
# 48                                                 b''     b'unid'       0
# 51                                                 b''    b'other'       0
# 93   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 105                                                b''      b'pwn'       0
# 108  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 114                                                b''      b'bin'       1
# centroids:
#    s_FLUX_U  s_FLUX_B  s_FLUX_V  s_FLUX_R  s_FLUX_I  s_FLUX_G  s_FLUX_J  \
# 0  0.000151  0.000189  0.000435  0.000133  0.000433  0.000474  0.016097
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000079
# 3  0.000000  0.023564  0.032294  0.000000  0.000000  0.024354  0.130946
# 4  0.004823  0.008225  0.017963  0.000607  0.036184  0.003097  0.044553
#
#    s_FLUX_H  s_FLUX_K  s_FLUX_u  s_FLUX_g  s_FLUX_r  s_FLUX_i  s_FLUX_z  \
# 0  0.032316  0.069654       0.0  0.000007  0.000077  0.000249       0.0
# 1  0.000000  0.000000       0.0  0.000000  0.000000  0.000000       0.0
# 2  0.015125  0.955688       0.0  0.000000  0.000000  0.000000       0.0
# 3  0.170236  0.222114       0.0  0.000000  0.000000  0.000000       0.0
# 4  0.085151  0.169448       0.0  0.000012  0.000086  0.000284       0.0
#
#    tev_0.3TeV  tev_1TeV  tev_3TeV  tev_10TeV  tev_30TeV
# 0    0.007257  0.485125  0.288574   0.096489   0.002339
# 1    0.000000  0.000000  0.000000   0.000000   0.000000
# 2    0.011160  0.007813  0.006451   0.002625   0.001060
# 3    0.063551  0.132081  0.081588   0.051620   0.067650
# 4    0.278659  0.191400  0.063444   0.029568   0.066495

# %% [markdown]
# * ### euclidean distance

# %%
# euclidean distance
from scipy.spatial.distance import euclidean
metric_function = "euclidean"
spectra_distances = pairwise_distances(spectra[spectrum_columns], metric=metric_function)

# %%
colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])

plt.subplots(figsize=(18, 6))
plt.subplot(131)
plt.title("PCA")
pca = PCA(n_components=2, random_state=42)
spectra_2D = pca.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(132)
plt.title("TSNE, Euclidean distance")
tsne = TSNE(n_components=2, random_state=42, learning_rate=500, n_iter=1500)
spectra_2D = tsne.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(133)
plt.title("TSNE, Chosen distance")
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=500)
spectra_2D = tsne.fit_transform(spectra_distances)
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)
plt.show()

# %%
# visualization - tsne with Euclidean distance
# tsne = TSNE(n_components=2, random_state=42)
# spectra_2D = tsne.fit_transform(spectra[spectrum_columns])

# visualization - tsne with chosen distance
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=500)
spectra_2D = tsne.fit_transform(spectra_distances)

plt.subplots(figsize=(18, 12))
plt.subplot(3, 3, 1)

colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])
plt.title("true labels")
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 
          'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']

for n in range(2, 10):
    kmeans = cluster.KMeans(n_clusters=n, random_state=42)
    cluster_labels = kmeans.fit_predict(spectra_distances)

    plt.subplot(3, 3, n)
    c = [colors[l] for l in cluster_labels]
    plt.title("cluster labels ({} clusters)".format(n))
    plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)
    
plt.show()

# %%
n = 6

kmeans = cluster.KMeans(n_clusters=n, random_state=42)
cluster_labels = kmeans.fit_predict(spectra_distances)
centers = []

spectra['KMeans_clusters_' + str(n)] = cluster_labels
for i in range(n):
    print("{} cluster".format(i))
    display(spectra[spectra['KMeans_clusters_' + str(n)] == i][other_names])
    centers.append(spectra.loc[spectra['KMeans_clusters_' + str(n)] == i, spectrum_columns].mean(axis=0).values)
centers = pd.DataFrame(np.column_stack(centers).T, columns=spectrum_columns)

# centroids
print("centroids:")
display(centers)
# plt.figure(figsize=(20, 10))
# sns.heatmap(centers, vmin=0, vmax=1)
# plt.show()
# Out:
# 0 cluster
#                             s_MAIN_ID s_class  \
# 61      b'[CHP2004] J095549.8+693934'    B0Ve
# 62                    b'[MTK2001b] 8'    B0Ve
# 63      b'[CHP2004] J095637.5+694137'    B0Ve
# 64           b'CXOU J095601.7+694308'    B0Ve
# 65           b'CXOU J095548.9+694010'    B0Ve
# 66           b'CXOU J095527.1+693923'    B0Ve
# 67           b'CXOU J095552.8+694020'    B0Ve
# 68           b'CXOU J095552.4+694024'    B0Ve
# 69           b'CXOU J095550.7+694039'    B0Ve
# 70           b'CXOU J095547.5+694120'    B0Ve
# 72           b'CXOU J095527.2+694050'    B0Ve
# 73           b'CXOU J095600.7+694107'    B0Ve
# 75           b'CXOU J095549.1+694036'    B0Ve
# 76           b'CXOU J095546.5+694040'    B0Ve
# 77           b'CXOU J095552.7+694045'    B0Ve
# 78           b'CXOU J095622.7+694134'    B0Ve
# 79           b'CXOU J095551.4+694035'    B0Ve
# 80           b'CXOU J095553.0+694048'    B0Ve
# 81           b'CXOU J095614.7+694249'    B0Ve
# 82           b'CXOU J095550.5+694056'    B0Ve
# 83           b'CXOU J095544.8+694100'    B0Ve
# 84           b'CXOU J095550.2+694039'    B0Ve
# 85            b'[RVZ2004] 40.49+57.4'    B0Ve
# 86           b'CXOU J095615.1+693951'    B0Ve
# 87   b'[SST2011] J095554.56+694100.4'    B0Ve
# 88           b'CXOU J095550.9+694044'    B0Ve
# 89           b'CXOU J095552.2+694042'    B0Ve
# 90           b'CXOU J095621.2+694224'    B0Ve
# 92           b'CXOU J095554.1+694039'    B0Ve
# 94   b'[SST2011] J095552.13+694053.1'    B0Ve
# 95           b'CXOU J095534.5+693823'    B0Ve
# 96           b'CXOU J095551.2+694012'    B0Ve
# 97           b'CXOU J095555.1+694027'    B0Ve
# 98           b'CXOU J095551.3+694043'    B0Ve
# 99           b'CXOU J095551.0+694050'    B0Ve
# 100          b'CXOU J095554.9+694038'    B0Ve
# 101          b'CXOU J095632.1+694127'    B0Ve
# 102                 b'NAME M82 ULX-1'    B0Ve
# 103     b'[CHP2004] J095630.9+694220'    B0Ve
# 104          b'CXOU J095550.6+694043'    B0Ve
# 106          b'CXOU J095608.0+694139'    B0Ve
# 107          b'CXOU J095624.6+694256'    B0Ve
# 109          b'CXOU J095531.8+693957'    B0Ve
# 111          b'CXOU J095553.3+694101'    B0Ve
# 112          b'CXOU J095546.1+694026'    B0Ve
# 113     b'[CHP2004] J095619.6+694146'    B0Ve
# 115          b'CXOU J095510.7+693955'    B0Ve
# 116          b'CXOU J095547.4+694059'    B0Ve
# 118          b'CXOU J095553.9+694045'    B0Ve
# 119        b'CXOM82 J095550.5+694022'    B0Ve
# 120          b'CXOU J095615.2+694142'    B0Ve
# 121          b'CXOU J095553.2+694052'    B0Ve
# 122          b'CXOU J095550.1+694034'    B0Ve
#
#                                        tev_fermi_names tev_classes  marked
# 61   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 62   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 63   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 64   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 65   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 66   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 67   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 68   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 69   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 70   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 72   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 73   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 75   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 76   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 77   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 78   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 79   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 80   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 81   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 82   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 83   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 84   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 85   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 86   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 87   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 88   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 89   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 90   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 92   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 94   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 95   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 96   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 97   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 98   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 99   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 100  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 101  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 102  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 103  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 104  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 106  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 107  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 109  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 111  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 112  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 113  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 115  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 116  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 118  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 119  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 120  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 121  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 122  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 1 cluster
#                       s_MAIN_ID s_class  \
# 3                    b'RMC 141'       B
# 9                     b'HTR 13'       B
# 16              b'CPD-69   416'       B
# 49                   b'RMC 142'    B0Ve
# 108  b'CXOM82 J095538.3+694030'    B0Ve
# 117                 b'Brey  84'    B0Ve
#
#                                        tev_fermi_names tev_classes  marked
# 3                                                  b''      b'pwn'       0
# 9                                                  b''      b'pwn'       0
# 16                                                 b''    b'other'       0
# 49                                                 b''      b'pwn'       0
# 108  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 117                                                b''      b'pwn'       0
# 2 cluster
#                             s_MAIN_ID s_class tev_fermi_names tev_classes  \
# 5               b'OGLE LMC-ECL-20994'       B             b''      b'pwn'
# 14     b'Cl* NGC 2070    SMB     283'       B             b''      b'pwn'
# 15  b'SSTISAGE1C J053736.75-690633.4'       B             b''      b'pwn'
# 17     b'Cl* NGC 2070    SMB     455'       O             b''      b'pwn'
# 18     b'Cl* NGC 2070    SMB     206'       O             b''      b'pwn'
# 19     b'Cl* NGC 2070    SMB     163'       O             b''      b'pwn'
# 20              b'OGLE LMC-ECL-21453'       O             b''      b'pwn'
# 21              b'OGLE LMC-ECL-21400'       O             b''      b'pwn'
# 26                        b'VFTS 318'       O             b''      b'pwn'
# 27                        b'VFTS 183'    B0Ve             b''      b'pwn'
# 28              b'OGLE LMC-ECL-21065'    B0Ve             b''      b'pwn'
# 29         b'2MASS J05371136-6905041'    B0Ve             b''      b'pwn'
# 31                     b'[ST92] 1-31'    B0Ve             b''      b'pwn'
# 33     b'Cl* NGC 2070    SMB     372'    B0Ve             b''      b'pwn'
# 39                         b'VFTS 50'    B0Ve             b''      b'pwn'
# 40                     b'[P93]   287'    B0Ve             b''      b'pwn'
# 41                     b'[P93] 10008'    B0Ve             b''      b'pwn'
# 42                        b'VFTS 347'    B0Ve             b''      b'pwn'
# 44                        b'VFTS 214'    B0Ve             b''      b'pwn'
# 45                        b'VFTS 610'    B0Ve             b''      b'pwn'
# 46                         b'VFTS 54'    B0Ve             b''      b'pwn'
# 47                     b'[P93]  1570'    B0Ve             b''      b'pwn'
# 50                     b'[P93]   930'    B0Ve             b''      b'pwn'
# 52       b'[AAA97b] J053634.4-691522'    B0Ve             b''      b'pwn'
# 53                        b'VFTS 313'    B0Ve             b''      b'pwn'
# 54                     b'[P93]  1235'    B0Ve             b''      b'pwn'
# 55                        b'VFTS 534'    B0Ve             b''      b'pwn'
# 56                        b'VFTS 374'    B0Ve             b''      b'pwn'
# 57              b'OGLE LMC-ECL-21425'    B0Ve             b''      b'pwn'
# 58         b'2MASS J05374020-6910068'    B0Ve             b''      b'pwn'
# 71           b'XMMU J053841.7-690514'    B0Ve             b''      b'pwn'
#
#     marked
# 5        0
# 14       0
# 15       0
# 17       0
# 18       0
# 19       0
# 20       0
# 21       0
# 26       0
# 27       0
# 28       0
# 29       0
# 31       0
# 33       0
# 39       0
# 40       0
# 41       0
# 42       0
# 44       0
# 45       0
# 46       0
# 47       0
# 50       0
# 52       0
# 53       0
# 54       0
# 55       0
# 56       0
# 57       0
# 58       0
# 71       0
# 3 cluster
#                       s_MAIN_ID s_class  \
# 2               b'SSTGC 519103'      Be
# 10           b'LS  IV -05   11'       B
# 23                  b'GCIRS  8'       O
# 30                 b'HD  43582'    B0Ve
# 36                b'[MT91] 213'    B0Ve
# 37   b'2MASS J05384705-6905016'    B0Ve
# 48                b'Schulte 21'    B0Ve
# 59           b'LS   I +61  303'    B0Ve
# 60                 b'HD 259440'    B0Ve
# 74              b'CPD-63  2495'    B0Ve
# 93                 b'SN 2004am'    B0Ve
# 114              b'V* V479 Sct'    B0Ve
#
#                                        tev_fermi_names tev_classes  marked
# 2                                                  b''     b'unid'       0
# 10                                                 b''     b'unid'       0
# 23                                                 b''     b'unid'       0
# 30                                                 b''      b'snr'       0
# 36                                                 b''     b'unid'       0
# 37                                                 b''      b'pwn'       0
# 48                                                 b''     b'unid'       0
# 59                                                 b''      b'bin'       1
# 60                                                 b''      b'bin'       1
# 74                                                 b''      b'bin'       1
# 93   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 114                                                b''      b'bin'       1
# 4 cluster
#                       s_MAIN_ID s_class tev_fermi_names tev_classes  marked
# 1    b'MSX6C G331.5487-00.5364'      Be             b''     b'unid'       0
# 12                 b'GCIRS  1W'       B             b''     b'unid'       0
# 22              b'[MCD2010] 18'       O             b''     b'unid'       0
# 24              b'[MCD2010] 13'       O             b''     b'unid'       0
# 25              b'[MCD2010] 13'       O             b''     b'unid'       0
# 110           b'[KRL2007b] 332'    B0Ve             b''     b'unid'       0
# 5 cluster
#                         s_MAIN_ID s_class       tev_fermi_names tev_classes  \
# 0             b'UCAC4 105-013663'      Be                   b''    b'other'
# 4    b'[AAA97b] J053648.7-691700'       B                   b''    b'other'
# 6                 b'[ST92] 2-62B'       B                   b''    b'other'
# 7                  b'[KKM2013] 7'       B                   b''  b'pwn,snr'
# 8                  b'[ST92] 2-62'       B                   b''    b'other'
# 11          b'[M2002] LMC 164553'       B                   b''    b'other'
# 13          b'[M2002] LMC 161594'       B                   b''    b'other'
# 32            b'[LSB2000] Star 2'    B0Ve                   b''    b'other'
# 34             b'UCAC2   1802729'    B0Ve                   b''    b'other'
# 35                 b'[ST92] 2-27'    B0Ve                   b''    b'other'
# 38                  b'[ST92] 2-8'    B0Ve                   b''    b'other'
# 43          b'[M2002] LMC 164299'    B0Ve                   b''    b'other'
# 51   b'[AAA97b] J053634.4-691522'    B0Ve                   b''    b'other'
# 91           b'2FGL J1019.0-5856'    B0Ve  b'1FGL J1018.6-5856'      b'bin'
# 105         b'2FHL J1633.5-4746e'    B0Ve                   b''      b'pwn'
#
#      marked
# 0         0
# 4         0
# 6         0
# 7         0
# 8         0
# 11        0
# 13        0
# 32        0
# 34        0
# 35        0
# 38        0
# 43        0
# 51        0
# 91        1
# 105       0
# centroids:
#    s_FLUX_U  s_FLUX_B  s_FLUX_V  s_FLUX_R  s_FLUX_I  s_FLUX_G  s_FLUX_J  \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.007903  0.049289  0.083741  0.001649  0.148953  0.020981  0.122714
# 2  0.000015  0.000147  0.000251  0.000012  0.000038  0.000041  0.000732
# 3  0.003468  0.001561  0.004561  0.000680  0.001127  0.006577  0.128136
# 4  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000079
# 5  0.002415  0.000724  0.004027  0.000086  0.000726  0.000617  0.001284
#
#    s_FLUX_H  s_FLUX_K  s_FLUX_u  s_FLUX_g  s_FLUX_r  s_FLUX_i  s_FLUX_z  \
# 0  0.000000  0.000000       0.0  0.000000  0.000000  0.000000       0.0
# 1  0.168122  0.226808       0.0  0.000000  0.000000  0.000000       0.0
# 2  0.001259  0.004346       0.0  0.000000  0.000000  0.000000       0.0
# 3  0.248499  0.509386       0.0  0.000045  0.000397  0.001298       0.0
# 4  0.015125  0.955688       0.0  0.000000  0.000000  0.000000       0.0
# 5  0.003263  0.007121       0.0  0.000000  0.000000  0.000000       0.0
#
#    tev_0.3TeV  tev_1TeV  tev_3TeV  tev_10TeV  tev_30TeV
# 0    0.000000  0.000000  0.000000   0.000000   0.000000
# 1    0.011563  0.087863  0.050019   0.017115   0.003282
# 2    0.008182  0.547648  0.325766   0.108924   0.002640
# 3    0.022777  0.038164  0.024170   0.008383   0.000771
# 4    0.011160  0.007813  0.006451   0.002625   0.001060
# 5    0.462309  0.265161  0.074444   0.046532   0.131291

# %% [markdown]
# * ### cosine distance

# %%
# cosine distance
# from scipy.spatial.distance import cosine
metric_function = "cosine"
spectra_distances = pairwise_distances(spectra[spectrum_columns], metric=metric_function)

# %%
colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])

plt.subplots(figsize=(18, 6))
plt.subplot(131)
plt.title("PCA")
pca = PCA(n_components=2, random_state=42)
spectra_2D = pca.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(132)
plt.title("TSNE, Euclidean distance")
tsne = TSNE(n_components=2, random_state=42, learning_rate=500, n_iter=1500)
spectra_2D = tsne.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(133)
plt.title("TSNE, Chosen distance")
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=400)
spectra_2D = tsne.fit_transform(spectra_distances)
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)
plt.show()

# %%
# visualization - tsne with Euclidean distance
# tsne = TSNE(n_components=2, random_state=42)
# spectra_2D = tsne.fit_transform(spectra[spectrum_columns])

# visualization - tsne with chosen distance
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=400)
spectra_2D = tsne.fit_transform(spectra_distances)

plt.subplots(figsize=(18, 12))
plt.subplot(3, 3, 1)

colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])
plt.title("true labels")
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 
          'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']

for n in range(2, 10):
    kmeans = cluster.KMeans(n_clusters=n, random_state=42)
    cluster_labels = kmeans.fit_predict(spectra_distances)

    plt.subplot(3, 3, n)
    c = [colors[l] for l in cluster_labels]
    plt.title("cluster labels ({} clusters)".format(n))
    plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)
    
plt.show()

# %%
n = 5

kmeans = cluster.KMeans(n_clusters=n, random_state=42)
cluster_labels = kmeans.fit_predict(spectra_distances)
centers = []

spectra['KMeans_clusters_' + str(n)] = cluster_labels
for i in range(n):
    print("{} cluster".format(i))
    display(spectra[spectra['KMeans_clusters_' + str(n)] == i][other_names])
    centers.append(spectra.loc[spectra['KMeans_clusters_' + str(n)] == i, spectrum_columns].mean(axis=0).values)
centers = pd.DataFrame(np.column_stack(centers).T, columns=spectrum_columns)

# centroids
print("centroids:")
display(centers)
# plt.figure(figsize=(20, 10))
# sns.heatmap(centers, vmin=0, vmax=1)
# plt.show()
# Out:
# 0 cluster
#                             s_MAIN_ID s_class tev_fermi_names tev_classes  \
# 5               b'OGLE LMC-ECL-20994'       B             b''      b'pwn'
# 14     b'Cl* NGC 2070    SMB     283'       B             b''      b'pwn'
# 15  b'SSTISAGE1C J053736.75-690633.4'       B             b''      b'pwn'
# 17     b'Cl* NGC 2070    SMB     455'       O             b''      b'pwn'
# 18     b'Cl* NGC 2070    SMB     206'       O             b''      b'pwn'
# 19     b'Cl* NGC 2070    SMB     163'       O             b''      b'pwn'
# 20              b'OGLE LMC-ECL-21453'       O             b''      b'pwn'
# 21              b'OGLE LMC-ECL-21400'       O             b''      b'pwn'
# 26                        b'VFTS 318'       O             b''      b'pwn'
# 27                        b'VFTS 183'    B0Ve             b''      b'pwn'
# 28              b'OGLE LMC-ECL-21065'    B0Ve             b''      b'pwn'
# 29         b'2MASS J05371136-6905041'    B0Ve             b''      b'pwn'
# 31                     b'[ST92] 1-31'    B0Ve             b''      b'pwn'
# 33     b'Cl* NGC 2070    SMB     372'    B0Ve             b''      b'pwn'
# 39                         b'VFTS 50'    B0Ve             b''      b'pwn'
# 40                     b'[P93]   287'    B0Ve             b''      b'pwn'
# 41                     b'[P93] 10008'    B0Ve             b''      b'pwn'
# 42                        b'VFTS 347'    B0Ve             b''      b'pwn'
# 44                        b'VFTS 214'    B0Ve             b''      b'pwn'
# 45                        b'VFTS 610'    B0Ve             b''      b'pwn'
# 46                         b'VFTS 54'    B0Ve             b''      b'pwn'
# 47                     b'[P93]  1570'    B0Ve             b''      b'pwn'
# 50                     b'[P93]   930'    B0Ve             b''      b'pwn'
# 52       b'[AAA97b] J053634.4-691522'    B0Ve             b''      b'pwn'
# 53                        b'VFTS 313'    B0Ve             b''      b'pwn'
# 54                     b'[P93]  1235'    B0Ve             b''      b'pwn'
# 55                        b'VFTS 534'    B0Ve             b''      b'pwn'
# 56                        b'VFTS 374'    B0Ve             b''      b'pwn'
# 57              b'OGLE LMC-ECL-21425'    B0Ve             b''      b'pwn'
# 58         b'2MASS J05374020-6910068'    B0Ve             b''      b'pwn'
# 71           b'XMMU J053841.7-690514'    B0Ve             b''      b'pwn'
#
#     marked
# 5        0
# 14       0
# 15       0
# 17       0
# 18       0
# 19       0
# 20       0
# 21       0
# 26       0
# 27       0
# 28       0
# 29       0
# 31       0
# 33       0
# 39       0
# 40       0
# 41       0
# 42       0
# 44       0
# 45       0
# 46       0
# 47       0
# 50       0
# 52       0
# 53       0
# 54       0
# 55       0
# 56       0
# 57       0
# 58       0
# 71       0
# 1 cluster
#                       s_MAIN_ID s_class tev_fermi_names tev_classes  marked
# 2               b'SSTGC 519103'      Be             b''     b'unid'       0
# 3                    b'RMC 141'       B             b''      b'pwn'       0
# 37   b'2MASS J05384705-6905016'    B0Ve             b''      b'pwn'       0
# 117                 b'Brey  84'    B0Ve             b''      b'pwn'       0
# 2 cluster
#                             s_MAIN_ID s_class  \
# 61      b'[CHP2004] J095549.8+693934'    B0Ve
# 62                    b'[MTK2001b] 8'    B0Ve
# 63      b'[CHP2004] J095637.5+694137'    B0Ve
# 64           b'CXOU J095601.7+694308'    B0Ve
# 65           b'CXOU J095548.9+694010'    B0Ve
# 66           b'CXOU J095527.1+693923'    B0Ve
# 67           b'CXOU J095552.8+694020'    B0Ve
# 68           b'CXOU J095552.4+694024'    B0Ve
# 69           b'CXOU J095550.7+694039'    B0Ve
# 70           b'CXOU J095547.5+694120'    B0Ve
# 72           b'CXOU J095527.2+694050'    B0Ve
# 73           b'CXOU J095600.7+694107'    B0Ve
# 75           b'CXOU J095549.1+694036'    B0Ve
# 76           b'CXOU J095546.5+694040'    B0Ve
# 77           b'CXOU J095552.7+694045'    B0Ve
# 78           b'CXOU J095622.7+694134'    B0Ve
# 79           b'CXOU J095551.4+694035'    B0Ve
# 80           b'CXOU J095553.0+694048'    B0Ve
# 81           b'CXOU J095614.7+694249'    B0Ve
# 82           b'CXOU J095550.5+694056'    B0Ve
# 83           b'CXOU J095544.8+694100'    B0Ve
# 84           b'CXOU J095550.2+694039'    B0Ve
# 85            b'[RVZ2004] 40.49+57.4'    B0Ve
# 86           b'CXOU J095615.1+693951'    B0Ve
# 87   b'[SST2011] J095554.56+694100.4'    B0Ve
# 88           b'CXOU J095550.9+694044'    B0Ve
# 89           b'CXOU J095552.2+694042'    B0Ve
# 90           b'CXOU J095621.2+694224'    B0Ve
# 92           b'CXOU J095554.1+694039'    B0Ve
# 94   b'[SST2011] J095552.13+694053.1'    B0Ve
# 95           b'CXOU J095534.5+693823'    B0Ve
# 96           b'CXOU J095551.2+694012'    B0Ve
# 97           b'CXOU J095555.1+694027'    B0Ve
# 98           b'CXOU J095551.3+694043'    B0Ve
# 99           b'CXOU J095551.0+694050'    B0Ve
# 100          b'CXOU J095554.9+694038'    B0Ve
# 101          b'CXOU J095632.1+694127'    B0Ve
# 102                 b'NAME M82 ULX-1'    B0Ve
# 103     b'[CHP2004] J095630.9+694220'    B0Ve
# 104          b'CXOU J095550.6+694043'    B0Ve
# 106          b'CXOU J095608.0+694139'    B0Ve
# 107          b'CXOU J095624.6+694256'    B0Ve
# 108        b'CXOM82 J095538.3+694030'    B0Ve
# 109          b'CXOU J095531.8+693957'    B0Ve
# 111          b'CXOU J095553.3+694101'    B0Ve
# 112          b'CXOU J095546.1+694026'    B0Ve
# 113     b'[CHP2004] J095619.6+694146'    B0Ve
# 115          b'CXOU J095510.7+693955'    B0Ve
# 116          b'CXOU J095547.4+694059'    B0Ve
# 118          b'CXOU J095553.9+694045'    B0Ve
# 119        b'CXOM82 J095550.5+694022'    B0Ve
# 120          b'CXOU J095615.2+694142'    B0Ve
# 121          b'CXOU J095553.2+694052'    B0Ve
# 122          b'CXOU J095550.1+694034'    B0Ve
#
#                                        tev_fermi_names tev_classes  marked
# 61   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 62   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 63   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 64   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 65   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 66   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 67   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 68   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 69   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 70   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 72   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 73   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 75   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 76   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 77   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 78   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 79   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 80   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 81   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 82   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 83   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 84   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 85   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 86   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 87   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 88   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 89   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 90   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 92   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 94   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 95   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 96   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 97   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 98   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 99   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 100  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 101  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 102  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 103  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 104  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 106  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 107  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 108  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 109  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 111  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 112  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 113  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 115  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 116  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 118  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 119  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 120  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 121  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 122  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 3 cluster
#                         s_MAIN_ID s_class       tev_fermi_names tev_classes  \
# 0             b'UCAC4 105-013663'      Be                   b''    b'other'
# 4    b'[AAA97b] J053648.7-691700'       B                   b''    b'other'
# 6                 b'[ST92] 2-62B'       B                   b''    b'other'
# 7                  b'[KKM2013] 7'       B                   b''  b'pwn,snr'
# 8                  b'[ST92] 2-62'       B                   b''    b'other'
# 11          b'[M2002] LMC 164553'       B                   b''    b'other'
# 13          b'[M2002] LMC 161594'       B                   b''    b'other'
# 32            b'[LSB2000] Star 2'    B0Ve                   b''    b'other'
# 34             b'UCAC2   1802729'    B0Ve                   b''    b'other'
# 35                 b'[ST92] 2-27'    B0Ve                   b''    b'other'
# 38                  b'[ST92] 2-8'    B0Ve                   b''    b'other'
# 43          b'[M2002] LMC 164299'    B0Ve                   b''    b'other'
# 51   b'[AAA97b] J053634.4-691522'    B0Ve                   b''    b'other'
# 91           b'2FGL J1019.0-5856'    B0Ve  b'1FGL J1018.6-5856'      b'bin'
# 105         b'2FHL J1633.5-4746e'    B0Ve                   b''      b'pwn'
#
#      marked
# 0         0
# 4         0
# 6         0
# 7         0
# 8         0
# 11        0
# 13        0
# 32        0
# 34        0
# 35        0
# 38        0
# 43        0
# 51        0
# 91        1
# 105       0
# 4 cluster
#                       s_MAIN_ID s_class  \
# 1    b'MSX6C G331.5487-00.5364'      Be
# 9                     b'HTR 13'       B
# 10           b'LS  IV -05   11'       B
# 12                 b'GCIRS  1W'       B
# 16              b'CPD-69   416'       B
# 22              b'[MCD2010] 18'       O
# 23                  b'GCIRS  8'       O
# 24              b'[MCD2010] 13'       O
# 25              b'[MCD2010] 13'       O
# 30                 b'HD  43582'    B0Ve
# 36                b'[MT91] 213'    B0Ve
# 48                b'Schulte 21'    B0Ve
# 49                   b'RMC 142'    B0Ve
# 59           b'LS   I +61  303'    B0Ve
# 60                 b'HD 259440'    B0Ve
# 74              b'CPD-63  2495'    B0Ve
# 93                 b'SN 2004am'    B0Ve
# 110           b'[KRL2007b] 332'    B0Ve
# 114              b'V* V479 Sct'    B0Ve
#
#                                        tev_fermi_names tev_classes  marked
# 1                                                  b''     b'unid'       0
# 9                                                  b''      b'pwn'       0
# 10                                                 b''     b'unid'       0
# 12                                                 b''     b'unid'       0
# 16                                                 b''    b'other'       0
# 22                                                 b''     b'unid'       0
# 23                                                 b''     b'unid'       0
# 24                                                 b''     b'unid'       0
# 25                                                 b''     b'unid'       0
# 30                                                 b''      b'snr'       0
# 36                                                 b''     b'unid'       0
# 48                                                 b''     b'unid'       0
# 49                                                 b''      b'pwn'       0
# 59                                                 b''      b'bin'       1
# 60                                                 b''      b'bin'       1
# 74                                                 b''      b'bin'       1
# 93   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 110                                                b''     b'unid'       0
# 114                                                b''      b'bin'       1
# centroids:
#    s_FLUX_U  s_FLUX_B  s_FLUX_V  s_FLUX_R  s_FLUX_I  s_FLUX_G  s_FLUX_J  \
# 0  0.000015  0.000147  0.000251  0.000012  0.000038  0.000041  0.000732
# 1  0.000000  0.006927  0.012428  0.000000  0.000000  0.003345  0.059077
# 2  0.000823  0.003277  0.006244  0.000000  0.008175  0.000000  0.000000
# 3  0.002415  0.000724  0.004027  0.000086  0.000726  0.000617  0.001284
# 4  0.002347  0.005779  0.008962  0.000950  0.024517  0.010075  0.107267
#
#    s_FLUX_H  s_FLUX_K  s_FLUX_u  s_FLUX_g  s_FLUX_r  s_FLUX_i  s_FLUX_z  \
# 0  0.001259  0.004346       0.0  0.000000  0.000000   0.00000       0.0
# 1  0.093220  0.433833       0.0  0.000000  0.000000   0.00000       0.0
# 2  0.000000  0.000000       0.0  0.000000  0.000000   0.00000       0.0
# 3  0.003263  0.007121       0.0  0.000000  0.000000   0.00000       0.0
# 4  0.195189  0.603804       0.0  0.000028  0.000251   0.00082       0.0
#
#    tev_0.3TeV  tev_1TeV  tev_3TeV  tev_10TeV  tev_30TeV
# 0    0.008182  0.547648  0.325766   0.108924   0.002640
# 1    0.039604  0.193316  0.117397   0.039385   0.001468
# 2    0.000000  0.000000  0.000000   0.000000   0.000000
# 3    0.462309  0.265161  0.074444   0.046532   0.131291
# 4    0.013224  0.013618  0.008383   0.003236   0.001549

# %% [markdown]
# * ### energy distance

# %%
# energy distance
metric_function = st.energy_distance
spectra_distances = pairwise_distances(spectra[spectrum_columns], metric=metric_function)

# %%
colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])

plt.subplots(figsize=(18, 6))
plt.subplot(131)
plt.title("PCA")
pca = PCA(n_components=2, random_state=42)
spectra_2D = pca.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(132)
plt.title("TSNE, Euclidean distance")
tsne = TSNE(n_components=2, random_state=42, learning_rate=500, n_iter=1500)
spectra_2D = tsne.fit_transform(spectra[spectrum_columns])
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

plt.subplot(133)
plt.title("TSNE, Chosen distance")
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=750)
spectra_2D = tsne.fit_transform(spectra_distances)
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)
plt.show()

# %%
# visualization - tsne with Euclidean distance
# tsne = TSNE(n_components=2, random_state=42)
# spectra_2D = tsne.fit_transform(spectra[spectrum_columns])

# visualization - tsne with chosen distance
tsne = TSNE(n_components=2, random_state=42, metric="precomputed", learning_rate=750)
spectra_2D = tsne.fit_transform(spectra_distances)

plt.subplots(figsize=(18, 12))
plt.subplot(3, 3, 1)

colors = ['red','black']
c = spectra['marked'].apply(lambda x: colors[x])
plt.title("true labels")
plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)

colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 
          'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']

for n in range(2, 10):
    kmeans = cluster.KMeans(n_clusters=n, random_state=42)
    cluster_labels = kmeans.fit_predict(spectra_distances)

    plt.subplot(3, 3, n)
    c = [colors[l] for l in cluster_labels]
    plt.title("cluster labels ({} clusters)".format(n))
    plt.scatter(spectra_2D[:, 0], spectra_2D[:, 1], c=c, alpha=0.5)
    
plt.show()

# %%
n = 7

kmeans = cluster.KMeans(n_clusters=n, random_state=42)
cluster_labels = kmeans.fit_predict(spectra_distances)
centers = []

spectra['KMeans_clusters_' + str(n)] = cluster_labels
for i in range(n):
    print("{} cluster".format(i))
    display(spectra[spectra['KMeans_clusters_' + str(n)] == i][other_names])
    centers.append(spectra.loc[spectra['KMeans_clusters_' + str(n)] == i, spectrum_columns].mean(axis=0).values)
centers = pd.DataFrame(np.column_stack(centers).T, columns=spectrum_columns)

# centroids
print("centroids:")
display(centers)
# plt.figure(figsize=(20, 10))
# sns.heatmap(centers, vmin=0, vmax=1)
# plt.show()
# Out:
# 0 cluster
#                             s_MAIN_ID s_class tev_fermi_names tev_classes  \
# 5               b'OGLE LMC-ECL-20994'       B             b''      b'pwn'
# 15  b'SSTISAGE1C J053736.75-690633.4'       B             b''      b'pwn'
# 17     b'Cl* NGC 2070    SMB     455'       O             b''      b'pwn'
# 18     b'Cl* NGC 2070    SMB     206'       O             b''      b'pwn'
# 19     b'Cl* NGC 2070    SMB     163'       O             b''      b'pwn'
# 20              b'OGLE LMC-ECL-21453'       O             b''      b'pwn'
# 21              b'OGLE LMC-ECL-21400'       O             b''      b'pwn'
# 26                        b'VFTS 318'       O             b''      b'pwn'
# 27                        b'VFTS 183'    B0Ve             b''      b'pwn'
# 28              b'OGLE LMC-ECL-21065'    B0Ve             b''      b'pwn'
# 29         b'2MASS J05371136-6905041'    B0Ve             b''      b'pwn'
# 31                     b'[ST92] 1-31'    B0Ve             b''      b'pwn'
# 33     b'Cl* NGC 2070    SMB     372'    B0Ve             b''      b'pwn'
# 39                         b'VFTS 50'    B0Ve             b''      b'pwn'
# 40                     b'[P93]   287'    B0Ve             b''      b'pwn'
# 41                     b'[P93] 10008'    B0Ve             b''      b'pwn'
# 42                        b'VFTS 347'    B0Ve             b''      b'pwn'
# 44                        b'VFTS 214'    B0Ve             b''      b'pwn'
# 45                        b'VFTS 610'    B0Ve             b''      b'pwn'
# 46                         b'VFTS 54'    B0Ve             b''      b'pwn'
# 47                     b'[P93]  1570'    B0Ve             b''      b'pwn'
# 52       b'[AAA97b] J053634.4-691522'    B0Ve             b''      b'pwn'
# 53                        b'VFTS 313'    B0Ve             b''      b'pwn'
# 54                     b'[P93]  1235'    B0Ve             b''      b'pwn'
# 55                        b'VFTS 534'    B0Ve             b''      b'pwn'
# 56                        b'VFTS 374'    B0Ve             b''      b'pwn'
# 57              b'OGLE LMC-ECL-21425'    B0Ve             b''      b'pwn'
# 58         b'2MASS J05374020-6910068'    B0Ve             b''      b'pwn'
# 71           b'XMMU J053841.7-690514'    B0Ve             b''      b'pwn'
#
#     marked
# 5        0
# 15       0
# 17       0
# 18       0
# 19       0
# 20       0
# 21       0
# 26       0
# 27       0
# 28       0
# 29       0
# 31       0
# 33       0
# 39       0
# 40       0
# 41       0
# 42       0
# 44       0
# 45       0
# 46       0
# 47       0
# 52       0
# 53       0
# 54       0
# 55       0
# 56       0
# 57       0
# 58       0
# 71       0
# 1 cluster
#                             s_MAIN_ID s_class  \
# 61      b'[CHP2004] J095549.8+693934'    B0Ve
# 62                    b'[MTK2001b] 8'    B0Ve
# 63      b'[CHP2004] J095637.5+694137'    B0Ve
# 64           b'CXOU J095601.7+694308'    B0Ve
# 65           b'CXOU J095548.9+694010'    B0Ve
# 66           b'CXOU J095527.1+693923'    B0Ve
# 67           b'CXOU J095552.8+694020'    B0Ve
# 68           b'CXOU J095552.4+694024'    B0Ve
# 69           b'CXOU J095550.7+694039'    B0Ve
# 70           b'CXOU J095547.5+694120'    B0Ve
# 72           b'CXOU J095527.2+694050'    B0Ve
# 73           b'CXOU J095600.7+694107'    B0Ve
# 75           b'CXOU J095549.1+694036'    B0Ve
# 76           b'CXOU J095546.5+694040'    B0Ve
# 77           b'CXOU J095552.7+694045'    B0Ve
# 78           b'CXOU J095622.7+694134'    B0Ve
# 79           b'CXOU J095551.4+694035'    B0Ve
# 80           b'CXOU J095553.0+694048'    B0Ve
# 81           b'CXOU J095614.7+694249'    B0Ve
# 82           b'CXOU J095550.5+694056'    B0Ve
# 83           b'CXOU J095544.8+694100'    B0Ve
# 84           b'CXOU J095550.2+694039'    B0Ve
# 85            b'[RVZ2004] 40.49+57.4'    B0Ve
# 86           b'CXOU J095615.1+693951'    B0Ve
# 87   b'[SST2011] J095554.56+694100.4'    B0Ve
# 88           b'CXOU J095550.9+694044'    B0Ve
# 89           b'CXOU J095552.2+694042'    B0Ve
# 90           b'CXOU J095621.2+694224'    B0Ve
# 92           b'CXOU J095554.1+694039'    B0Ve
# 94   b'[SST2011] J095552.13+694053.1'    B0Ve
# 95           b'CXOU J095534.5+693823'    B0Ve
# 96           b'CXOU J095551.2+694012'    B0Ve
# 97           b'CXOU J095555.1+694027'    B0Ve
# 98           b'CXOU J095551.3+694043'    B0Ve
# 99           b'CXOU J095551.0+694050'    B0Ve
# 100          b'CXOU J095554.9+694038'    B0Ve
# 101          b'CXOU J095632.1+694127'    B0Ve
# 102                 b'NAME M82 ULX-1'    B0Ve
# 103     b'[CHP2004] J095630.9+694220'    B0Ve
# 104          b'CXOU J095550.6+694043'    B0Ve
# 106          b'CXOU J095608.0+694139'    B0Ve
# 107          b'CXOU J095624.6+694256'    B0Ve
# 109          b'CXOU J095531.8+693957'    B0Ve
# 111          b'CXOU J095553.3+694101'    B0Ve
# 112          b'CXOU J095546.1+694026'    B0Ve
# 113     b'[CHP2004] J095619.6+694146'    B0Ve
# 115          b'CXOU J095510.7+693955'    B0Ve
# 116          b'CXOU J095547.4+694059'    B0Ve
# 118          b'CXOU J095553.9+694045'    B0Ve
# 119        b'CXOM82 J095550.5+694022'    B0Ve
# 120          b'CXOU J095615.2+694142'    B0Ve
# 121          b'CXOU J095553.2+694052'    B0Ve
# 122          b'CXOU J095550.1+694034'    B0Ve
#
#                                        tev_fermi_names tev_classes  marked
# 61   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 62   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 63   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 64   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 65   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 66   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 67   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 68   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 69   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 70   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 72   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 73   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 75   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 76   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 77   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 78   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 79   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 80   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 81   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 82   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 83   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 84   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 85   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 86   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 87   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 88   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 89   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 90   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 92   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 94   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 95   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 96   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 97   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 98   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 99   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 100  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 101  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 102  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 103  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 104  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 106  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 107  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 109  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 111  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 112  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 113  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 115  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 116  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 118  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 119  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 120  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 121  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 122  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 2 cluster
#                  s_MAIN_ID s_class       tev_fermi_names tev_classes  marked
# 7           b'[KKM2013] 7'       B                   b''  b'pwn,snr'       0
# 9                b'HTR 13'       B                   b''      b'pwn'       0
# 10      b'LS  IV -05   11'       B                   b''     b'unid'       0
# 30            b'HD  43582'    B0Ve                   b''      b'snr'       0
# 43   b'[M2002] LMC 164299'    B0Ve                   b''    b'other'       0
# 49              b'RMC 142'    B0Ve                   b''      b'pwn'       0
# 91    b'2FGL J1019.0-5856'    B0Ve  b'1FGL J1018.6-5856'      b'bin'       1
# 117            b'Brey  84'    B0Ve                   b''      b'pwn'       0
# 3 cluster
#                           s_MAIN_ID s_class tev_fermi_names tev_classes  \
# 0               b'UCAC4 105-013663'      Be             b''    b'other'
# 4      b'[AAA97b] J053648.7-691700'       B             b''    b'other'
# 6                   b'[ST92] 2-62B'       B             b''    b'other'
# 8                    b'[ST92] 2-62'       B             b''    b'other'
# 11            b'[M2002] LMC 164553'       B             b''    b'other'
# 13            b'[M2002] LMC 161594'       B             b''    b'other'
# 14   b'Cl* NGC 2070    SMB     283'       B             b''      b'pwn'
# 32              b'[LSB2000] Star 2'    B0Ve             b''    b'other'
# 34               b'UCAC2   1802729'    B0Ve             b''    b'other'
# 35                   b'[ST92] 2-27'    B0Ve             b''    b'other'
# 38                    b'[ST92] 2-8'    B0Ve             b''    b'other'
# 51     b'[AAA97b] J053634.4-691522'    B0Ve             b''    b'other'
# 105           b'2FHL J1633.5-4746e'    B0Ve             b''      b'pwn'
#
#      marked
# 0         0
# 4         0
# 6         0
# 8         0
# 11        0
# 13        0
# 14        0
# 32        0
# 34        0
# 35        0
# 38        0
# 51        0
# 105       0
# 4 cluster
#                       s_MAIN_ID s_class tev_fermi_names tev_classes  marked
# 1    b'MSX6C G331.5487-00.5364'      Be             b''     b'unid'       0
# 12                 b'GCIRS  1W'       B             b''     b'unid'       0
# 22              b'[MCD2010] 18'       O             b''     b'unid'       0
# 24              b'[MCD2010] 13'       O             b''     b'unid'       0
# 25              b'[MCD2010] 13'       O             b''     b'unid'       0
# 110           b'[KRL2007b] 332'    B0Ve             b''     b'unid'       0
# 5 cluster
#           s_MAIN_ID s_class tev_fermi_names tev_classes  marked
# 3        b'RMC 141'       B             b''      b'pwn'       0
# 16  b'CPD-69   416'       B             b''    b'other'       0
# 6 cluster
#                       s_MAIN_ID s_class  \
# 2               b'SSTGC 519103'      Be
# 23                  b'GCIRS  8'       O
# 36                b'[MT91] 213'    B0Ve
# 37   b'2MASS J05384705-6905016'    B0Ve
# 48                b'Schulte 21'    B0Ve
# 50               b'[P93]   930'    B0Ve
# 59           b'LS   I +61  303'    B0Ve
# 60                 b'HD 259440'    B0Ve
# 74              b'CPD-63  2495'    B0Ve
# 93                 b'SN 2004am'    B0Ve
# 108  b'CXOM82 J095538.3+694030'    B0Ve
# 114              b'V* V479 Sct'    B0Ve
#
#                                        tev_fermi_names tev_classes  marked
# 2                                                  b''     b'unid'       0
# 23                                                 b''     b'unid'       0
# 36                                                 b''     b'unid'       0
# 37                                                 b''      b'pwn'       0
# 48                                                 b''     b'unid'       0
# 50                                                 b''      b'pwn'       0
# 59                                                 b''      b'bin'       1
# 60                                                 b''      b'bin'       1
# 74                                                 b''      b'bin'       1
# 93   b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 108  b'1FGL J0956.5+6938,2FGL J0955.9+6936,3FGL J09...   b'galaxy'       0
# 114                                                b''      b'bin'       1
# centroids:
#    s_FLUX_U  s_FLUX_B  s_FLUX_V  s_FLUX_R  s_FLUX_I  s_FLUX_G  s_FLUX_J  \
# 0  0.000016  0.000024  0.000076  0.000013  0.000041  0.000044  0.000181
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.007676  0.005766  0.013276  0.001237  0.057577  0.010266  0.110302
# 3  0.001110  0.000503  0.004202  0.000100  0.000198  0.000238  0.000661
# 4  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000079
# 5  0.000000  0.046729  0.055118  0.000000  0.000000  0.054196  0.162884
# 6  0.004118  0.015255  0.029340  0.000680  0.037913  0.001703  0.091154
#
#    s_FLUX_H  s_FLUX_K  s_FLUX_u  s_FLUX_g  s_FLUX_r  s_FLUX_i  s_FLUX_z  \
# 0  0.000247  0.000318       0.0  0.000000  0.000000  0.000000       0.0
# 1  0.000000  0.000000       0.0  0.000000  0.000000  0.000000       0.0
# 2  0.162642  0.217746       0.0  0.000000  0.000000  0.000000       0.0
# 3  0.001514  0.008895       0.0  0.000000  0.000000  0.000000       0.0
# 4  0.015125  0.955688       0.0  0.000000  0.000000  0.000000       0.0
# 5  0.189861  0.219344       0.0  0.000000  0.000000  0.000000       0.0
# 6  0.197582  0.450793       0.0  0.000045  0.000397  0.001298       0.0
#
#    tev_0.3TeV  tev_1TeV  tev_3TeV  tev_10TeV  tev_30TeV
# 0    0.008230  0.550892  0.327695   0.109569   0.002655
# 1    0.000000  0.000000  0.000000   0.000000   0.000000
# 2    0.136837  0.121977  0.059901   0.036819   0.057978
# 3    0.450555  0.289194  0.083744   0.042789   0.116298
# 4    0.011160  0.007813  0.006451   0.002625   0.001060
# 5    0.032731  0.132539  0.072105   0.025279   0.009214
# 6    0.022911  0.080282  0.049194   0.016586   0.000750
